# %% [markdown]
# <a href="https://colab.research.google.com/github/Moin199/Moin199.github.io/blob/master/Keras_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('/content/kc_house_data.csv')

# %%
df.isnull().any()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
df.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.159700e+04  2.159700e+04  ...   21597.000000   21597.000000
# mean   4.580474e+09  5.402966e+05  ...    1986.620318   12758.283512
# std    2.876736e+09  3.673681e+05  ...     685.230472   27274.441950
# min    1.000102e+06  7.800000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.220000e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
df.corr()
# Out:
#                      id     price  ...  sqft_living15  sqft_lot15
# id             1.000000 -0.016772  ...      -0.002701   -0.138557
# price         -0.016772  1.000000  ...       0.585241    0.082845
# bedrooms       0.001150  0.308787  ...       0.393406    0.030690
# bathrooms      0.005162  0.525906  ...       0.569884    0.088303
# sqft_living   -0.012241  0.701917  ...       0.756402    0.184342
# sqft_lot      -0.131911  0.089876  ...       0.144763    0.718204
# floors         0.018608  0.256804  ...       0.280102   -0.010722
# waterfront    -0.002727  0.266398  ...       0.086507    0.030781
# view           0.011536  0.397370  ...       0.280681    0.072904
# condition     -0.023803  0.036056  ...      -0.093072   -0.003126
# grade          0.008188  0.667951  ...       0.713867    0.120981
# sqft_above    -0.010799  0.605368  ...       0.731767    0.195077
# sqft_basement -0.005193  0.323799  ...       0.200443    0.017550
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['price'],df['long'])

# %%
sns.scatterplot(df['long'],df['lat'],hue=df['price'],alpha=0.3,edgecolor=None)

# %%
len(df)*0.01
# Out:
# 215.97

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  ...     long  sqft_living15  sqft_lot15
# 7245   6762700020  10/13/2014  7700000.0  ... -122.323           3940        8800
# 3910   9808700762   6/11/2014  7060000.0  ... -122.214           3930       25449
# 9245   9208900037   9/19/2014  6890000.0  ... -122.240           4540       42730
# 4407   2470100110    8/4/2014  5570000.0  ... -122.233           3560       24345
# 1446   8907500070   4/13/2015  5350000.0  ... -122.220           4600       21750
# 1313   7558700030   4/13/2015  5300000.0  ... -122.210           4320       24619
# 1162   1247600105  10/20/2014  5110000.0  ... -122.211           3430       26788
# 8085   1924059029   6/17/2014  4670000.0  ... -122.210           3270       10454
# 2624   7738500731   8/15/2014  4500000.0  ... -122.280           3030       23408
# 8629   3835500195   6/18/2014  4490000.0  ... -122.219           3720       14592
# ...

# %%
non_one_percent=df.sort_values('price',ascending=False).iloc[216:]

# %%
sns.scatterplot(non_one_percent['long'],non_one_percent['lat'],hue=non_one_percent['price'],alpha=0.3,edgecolor=None)

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
df=df.drop(['id'],axis=1)

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['Year']=df['date'].apply(lambda date: date.year)
df['Month']=df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  ...  sqft_lot15  Year  Month
# 0 2014-10-13  221900.0         3  ...        5650  2014     10
# 1 2014-12-09  538000.0         3  ...        7639  2014     12
# 2 2015-02-25  180000.0         2  ...        8062  2015      2
# 3 2014-12-09  604000.0         4  ...        5000  2014     12
# 4 2015-02-18  510000.0         3  ...        7503  2015      2
#
# [5 rows x 22 columns]

# %%
df.groupby('Year').mean()['price'].plot()

# %%
df=df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'Year', 'Month'],
#       dtype='object')

# %%
df=df.drop('zipcode',axis=1)

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(19,'relu'))
model.add(Dense(19,'relu'))
model.add(Dense(19,'relu'))
model.add(Dense(19,'relu'))

model.add(Dense(1))
model.compile('adam',loss='mse')

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=128,epochs=400)
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 0s 23us/sample - loss: 427711510223.0422 - val_loss: 405038240097.9753
# Epoch 2/400
# 15117/15117 [==============================] - 0s 16us/sample - loss: 345878609323.9029 - val_loss: 222857421912.4938
# Epoch 3/400
# 15117/15117 [==============================] - 0s 16us/sample - loss: 137789383034.7926 - val_loss: 96001971025.5407
# Epoch 4/400
# 15117/15117 [==============================] - 0s 16us/sample - loss: 98108234026.1840 - val_loss: 93775615903.9210
# Epoch 5/400
# 15117/15117 [==============================] - 0s 16us/sample - loss: 95828360743.4576 - val_loss: 91722922777.9160
# Epoch 6/400
# 15117/15117 [==============================] - 0s 18us/sample - loss: 93577740551.6375 - val_loss: 89538070745.4420
# Epoch 7/400
# 15117/15117 [==============================] - 0s 16us/sample - loss: 91350986041.0187 - val_loss: 87545924251.4963
# Epoch 8/400
# ...

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses
# Out:
#              loss      val_loss
# 0    4.277115e+11  4.050382e+11
# 1    3.458786e+11  2.228574e+11
# 2    1.377894e+11  9.600197e+10
# 3    9.810823e+10  9.377562e+10
# 4    9.582836e+10  9.172292e+10
# ..            ...           ...
# 395  2.913578e+10  2.666202e+10
# 396  2.909816e+10  2.667360e+10
# 397  2.910811e+10  2.663272e+10
# 398  2.906875e+10  2.661054e+10
# 399  2.907229e+10  2.662022e+10
#
# [400 rows x 2 columns]

# %%
losses.plot()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
predictions=model.predict(x_test)

# %%
mean_squared_error(y_test,predictions)**0.5
# Out:
# 163157.05402213824

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 101093.45235339506

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7992852730567639
